# %%
# 1. Написать решения уравнений.
      # Формула по которой решал уравнения: b ** 2 - 4 * a * c
      # коэффициенты в уравнениях (a, b, c)

# y ** 2 - 12 * y + 20 = 0
a = 1
b = -12
c = 20
d = b**2 - 4 * a * c
x1 = (-b + d ** 0.5) / (2 * a)
x2 = (-b - d ** 0.5) / (2 * a)
print(f'x1 = {x1}, x2 = {x2}')

# z ** 2 + 17 * z + 72 = 0
a = 1
b = 17
c = 72
d = b**2 - 4 * a * c
x1 = (-b + d ** 0.5) / (2 * a)
x2 = (-b - d ** 0.5) / (2 * a)
print(f'x1 = {x1}, x2 = {x2}')

# x ** 2 - 7 * x - 44 = 0
a = 1
b = -7
c = -44
d = b**2 - 4 * a * c
x1 = (-b + d ** 0.5) / (2 * a)
x2 = (-b - d ** 0.5) / (2 * a)
print(f'x1 = {x1}, x2 = {x2}')

# y ** 2 + 9 * y + 8 = 0
a = 1
b = 9
c = 8
d = b**2 - 4 * a * c
x1 = (-b + d ** 0.5) / (2 * a)
x2 = (-b - d ** 0.5) / (2 * a)
print(f'x1 = {x1}, x2 = {x2}')

# h ** 2 - 2 * b - 63 = 0
a = 1
b = -2
c = -63
d = b**2 - 4 * a * c
x1 = (-b + d ** 0.5) / (2 * a)
x2 = (-b - d ** 0.5) / (2 * a)
print(f'x1 = {x1}, x2 = {x2}')
# Out:
# x1 = 10.0, x2 = 2.0
# x1 = -8.0, x2 = -9.0
# x1 = 11.0, x2 = -4.0
# x1 = -1.0, x2 = -8.0
# x1 = 9.0, x2 = -7.0

# %%
# 2. Дан произвольный список.

name = ["Anna", "Alice", "Bob", "Chris"]
print(type(name))

# Представьте его в обратном порядке.

print(name[3], name[2], name[1], name[0])
# Out:
# <class 'list'>
# Chris Bob Alice Anna

# %%
# 3. Принимаем список и меняем местами его первый и последний элемент.

lst = [1, 2, 3, 4, 5]

def change(lst):

    a = lst[4], lst[1], lst[2], lst[3], lst[0]
    print(a)

change(lst) #ps. я так понял что в этом задании нужно изменить список,
                 # который нам дан при помощи фунции "change"
# Out:
# (5, 2, 3, 4, 1)

# %%
# 4. Берем произвольный список чисел, находим самое большое число,
     # делим его на len - длину списка.

lst = [1, 2, 28, 9, 13]
print(len(lst)) # длина списка

max_a = lst[0]
min_a = lst[0]

for value in lst[1:5]:
    if (value > max_a):
        max_a = value

useless = max_a / len(lst)

print(useless)
# Out:
# 5
# 5.6
